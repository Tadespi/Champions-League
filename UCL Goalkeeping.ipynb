# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Import CSV
goal_keeper = pd.read_csv('../Champions_League_2022/Resources/goalkeeping.csv')
goal_keeper.head()
# Out:
#    serial   player_name         club    position  saved  conceded  \
# 0       1      Courtois  Real Madrid  Goalkeeper     61        14
# 1       2         Rulli   Villarreal  Goalkeeper     41        16
# 2       3   Vlachodimos      Benfica  Goalkeeper     38        17
# 3       4  Athanasiadis      Sheriff  Goalkeeper     29         8
# 4       5      Mignolet  Club Brugge  Goalkeeper     28        20
#
#    saved_penalties  cleansheets  punches made  match_played
# 0                1            5             4            13
# 1                0            3            12            12
# 2                1            5             5            10
# 3                0            1             2             5
# 4                0            0             1             6

# %%
# Five best goalies based on 'saved'
five_best = goal_keeper[['player_name', 'saved']]
five_best.head()
# Out:
#     player_name  saved
# 0      Courtois     61
# 1         Rulli     41
# 2   Vlachodimos     38
# 3  Athanasiadis     29
# 4      Mignolet     28

# %%
# Five worst goalies based on Saves
five_worst = goal_keeper[['player_name', 'saved']]
five_worst.tail()
# Out:
#    player_name  saved
# 48    Martínez      3
# 49       Onana      2
# 50       Perin      2
# 51  Shevchenko      1
# 52      Carson      1
